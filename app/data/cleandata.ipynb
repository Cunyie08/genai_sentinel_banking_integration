# %%
import pandas as pd
complaints = pd.read_csv("complaints.csv")
customers = pd.read_csv("customers.csv")

# %%
customer_ids = customers["customer_id"]
legit_complaints = complaints[complaints["customer_id"].isin(customer_ids)]

# %%
customer_ids
# Out:
# 0       b5af208d-1d66-44d8-81c5-92883eb9b77c
# 1       a3b26886-ab2c-4421-a6d3-51594aca86fe
# 2       8109075f-30cd-4a46-9920-b8e7441649bd
# 3       314dcdc6-14aa-4423-a2aa-3f7645def3b2
# 4       2450649e-85d7-4290-b015-afff897cf35b
#                         ...
# 2995    a6ba6910-25d9-49a3-a532-8c623a16589e
# 2996    ac409951-5c71-4399-a487-f21ac715fe11
# 2997    2271ac5e-4719-48ed-a0b7-1c31a46d5c97
# 2998    025e7eb5-6c5d-487e-9168-16ebf4b31b38
# 2999    b9f394c8-dcd0-4779-bc90-558a95c545d3
# Name: customer_id, Length: 3000, dtype: str

# %%
legit_complaints
# Out:
# Empty DataFrame
# Columns: [complaint_id, customer_id, linked_transaction_id, linked_reference, department_code, department_name, priority_level, sentiment, complaint_channel, assigned_agent_id, complaint_timestamp, resolution_timestamp, resolution_time_hours, sla_hours_limit, sla_breach_flag, complaint_status, fraud_related, complaint_text, complaint_narration]
# Index: []

# %%
complaints["customer_id"]
# Out:
# 0        2b65ee56-991e-4377-9395-69f29ca99cb5
# 1        2b65ee56-991e-4377-9395-69f29ca99cb5
# 2        2b65ee56-991e-4377-9395-69f29ca99cb5
# 3        2b65ee56-991e-4377-9395-69f29ca99cb5
# 4        485638ae-1b64-442a-a1b7-37bb58823863
#                          ...
# 29582    32781809-b46b-44ae-be18-3cd6d65a17bd
# 29583    2e286536-dd4f-4cfe-9047-dcd0b03d00b6
# 29584    2e286536-dd4f-4cfe-9047-dcd0b03d00b6
# 29585    2e286536-dd4f-4cfe-9047-dcd0b03d00b6
# 29586    2e286536-dd4f-4cfe-9047-dcd0b03d00b6
# Name: customer_id, Length: 29587, dtype: str

# %%
customers
